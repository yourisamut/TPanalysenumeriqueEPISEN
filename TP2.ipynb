# %% [markdown]
# <table style="width:100%; border-bottom: 2px solid #333; padding-bottom: 10px; margin-bottom: 20px;">
#   <tr>
#     <td style="text-align: left; font-size: 1.3em; font-weight: bold;">EPISEN</td>
#     <td style="text-align: right; font-size: 0.9em;"><strong>TP2 - Analyse numérique et mathématiques</strong><br/><span style="font-size: 0.85em;">1FI  &bull; 2026-2027</span></td>
#   </tr>
# </table>
#
# <div style="text-align: center; margin: 30px 0;">
#   <h1>TP2 - Intégration numérique</h1>
# </div>

# %% [markdown]
# <div style="border: 1px solid #333; padding: 8px 16px; margin: 20px 0; display: inline-block;">
#   <strong>Nom : Valjean</strong> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#   <strong>Prénom : Jean</strong>
# </div>

# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 1 - Méthode des rectangles</h3>
# </div>
#
# On s'intéresse à la fonction $\varphi$ définie par $\varphi(t)=\dfrac{1}{25+t^2}$.

# %% [markdown]
# > 📝 **Question 1 —** Montrer que $I(\varphi)=\displaystyle\int_0^1 \varphi(t)\mathrm{d}t = \dfrac{1}{5}\arctan\left(\dfrac{1}{5}\right)$.

# %% [markdown]
# Sur feuille ?

# %% [markdown]
# > 💻 **Question 2 —** Définir la fonction $\varphi$ sur python.

# %% [markdown]
# > 💻 **Question 3 —** Écrire une fonction `rect(f, a, b, n)` qui, pour toute fonction $f$, approche $I(f)$, son intégrale sur $[a;b]$, par la méthode des rectangles à gauche avec $n$ sous-intervalles de même largeur.

# %% [markdown]
# > 💻 **Question 4 —** Écrire une fonction `rect1(f, a, b)` qui, pour toute fonction $f$, renvoie la liste des approximations $I_n(f)$ de $I(f)$ par la méthode des rectangles à gauche pour $n = 1, 2, \dots, 100$.

# %% [markdown]
# > 💻 **Question 5 —** Écrire un script qui trace les approximations de $I(\varphi)$ par la méthode des rectangles à gauche avec subdivision régulière, en fonction de $n$, pour $n = 1, 2, \dots, 100$. On fera apparaître en pointillés rouges la droite $y = \frac{1}{5}\arctan\left(\frac{1}{5}\right)$ correspondant à la valeur exacte de l'intégrale.

# %% [markdown]
# > 📝 **Question 6 —** Rappeler l'ordre de l'erreur globale $e_n=\lvert I_n(\varphi) - I(\varphi) \lvert$ de la méthode des rectangles.
# >
# >  Justifier qu'il existe une constante $C$ telle que $e_n\leq \dfrac{C}{n}$. Déterminer la valeur exacte de $C$.

# %% [markdown]
# Blabla..

# %% [markdown]
# > 📝 **Question 7 —** Justifier que $\log(e_n)\leq -\log(n)+\log(C)$.

# %% [markdown]
# > 💻 **Question 8 —** En utilisant `rect1`, calculer la liste des erreurs globales d'approximations $e_n=\lvert I_n(\varphi) - I(\varphi) \lvert$ pour $n=1,2,\dots,100$.

# %% [markdown]
# > 💻 **Question 9 —** Tracer $\log(e_n)$ en fonction de $\log(n)$ pour $n=1,2,\dots,100$.

# %% [markdown]
# > 📝  **Question 10 —** Quel coefficient directeur observez-vous ? Est-ce cohérent avec la question 7 ?

# %% [markdown]
# Je constate que...

# %% [markdown]
# > 📝  **Question 11 —** Quelle ordonnée à l'origine observez-vous ? Est-ce cohérent avec la question 6 ?

# %% [markdown]
# J'observe que...

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 2 - Méthode des trapèzes</h3>
# </div>
#
# On s'intéresse encore à la fonction $\varphi$ définie par $\varphi(t)=\dfrac{1}{25+t^2}$.

# %% [markdown]
# > 💻 **Question 12 —** Refaire les question 3, 4, 5, 8 et 9 avec la méthode des trapèzes.

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 3 - Méthode du point milieu</h3>
# </div>
#
# On s'intéresse encore à la fonction $\varphi$ définie par $\varphi(t)=\dfrac{1}{25+t^2}$.

# %% [markdown]
# > 💻 **Question 13 —** Refaire les question 3, 4, 5, 8 et 9 avec la méthode du point milieu.

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 4 - Comparaison des méthodes</h3>
# </div>
#
# On s'intéresse encore à la fonction $\varphi$ définie par $\varphi(t)=\dfrac{1}{25+t^2}$.

# %% [markdown]
# > 💻 **Question 14 —** Écrire un script permettant de comparer <b>visuellement et clairement</b> la vitesse de convergence vers $I(\varphi)$ des trois méthodes : rectangles à gauche, trapèzes et point milieu.

# %% [markdown]
# > 📝  **Question 15 —** Que constatez-vous ? Est-ce cohérent avec le cours et les ordres d'erreurs ?

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 5 - Méthode de Simpson</h3>
# </div>
#
# On s'intéresse encore à la fonction $\varphi$ définie par $\varphi(t)=\dfrac{1}{25+t^2}$.

# %% [markdown]
# > 💻 **Question 16 —** Implémenter la méthode de Simpson puis l'essayer sur la fonction $\varphi$.

# %% [markdown]
# > 💻 **Question 17 —** Déterminer combien d'itérations sont-elles nécessaires pour avoir une estimation proche à $10^{-5}$, $10^{-10}$, $10^{-15}$, $10^{-50}$, $10^{-100}$ et $10^{-200}$ de $I(\varphi)$ avec la méthode de Simpson.

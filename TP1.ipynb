# %% [markdown]
# <table style="width:100%; border-bottom: 2px solid #333; padding-bottom: 10px; margin-bottom: 20px;">
#   <tr>
#     <td style="text-align: left; font-size: 1.3em; font-weight: bold;">EPISEN</td>
#     <td style="text-align: right; font-size: 0.9em;"><strong>TP1 — Outils mathématiques</strong><br/><span style="font-size: 0.85em;">1FI  &bull; 2026-2027</span></td>
#   </tr>
# </table>
#
# <div style="text-align: center; margin: 30px 0;">
#   <h1>TP1 Résolution de systèmes linéaires</h1>
# </div>

# %% [markdown]
# <div style="border: 1px solid #333; padding: 8px 16px; margin: 20px 0; display: inline-block;">
#   <strong>Nom : Valjean</strong> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#   <strong>Prénom : Jean</strong>
# </div>

# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 1 - Décomposition de Cholesky et résolution de systèmes triangulaires</h3>
# </div>
#
# On s'intéresse à l'équation $A_1X=B_1$ où $A_1 =\begin{pmatrix} 1 & 1 & 1 & 1 \\ 1 & 5 & 5 & 5 \\ 1 & 5 & 14 & 14 \\ 1 & 5 & 14 & 15 \end{pmatrix}$ et $B_1=\begin{pmatrix} 4\\16\\34\\35\\ \end{pmatrix}$.

# %% [markdown]
# > 📝 **Question 1 —** À l'aide de l'algorithme du Pivot de Gauss, résoudre l'équation $A_1X=B_1$.

# %% [markdown]
# Le vecteur solution est $X=\begin{pmatrix} ? \\ ? \\ ? \\ ? \\ \end{pmatrix}$.

# %% [markdown]
# > 💻 **Question 2 —** Coder la matrice $A_1$ et le vecteur $B_1$ en Python.

# %% [markdown]
# > 💻 **Question 3 —** Déterminer rapidement le spectre de $A_1$.

# %% [markdown]
# > 📝 **Question 4 —** La matrice $A_1$ possède-t-elle une décomposition de Cholesky ? Justifier votre réponse.

# %% [markdown]
# Blablabla ...

# %% [markdown]
# > 💻 **Question 5 —** Déterminer cette décomposition.

# %% [markdown]
# > 💻 **Question 6 —** Compléter la fonction `lower(L,Y)` qui prend en un argument une matrice triangulaire inférieure $L$ et un vecteur $Y$ et rend le vecteur $Y$, solution de l'équation $LY=B$.

# %%
def lower(L, B):
    n = len(B)
    Y = ???
    for i in range(n):
        s = 0
        for j in range(???):
            s += ???
        Y[i] = (B[i] - s) / ???
    return Y
# Out:
#   Cell In[80], line 3
#     Y = ???
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# > 💻 **Question 7 —** Écrire la fonction `upper(U,Y)` qui prend en un argument une matrice triangulaire supérieure $U$ et un vecteur $Y$ et rend le vecteur $X$, solution de l'équation $UX=Y$.
# > <div style="background-color:#f5f5f5; border-left: 4px solid #aaa; padding: 8px 16px; margin: 10px 0;">
#   <p style="margin:0;">💡 <strong>Indication —</strong> <code>range(n-1, -1, -1)</code> parcourt les indices en sens inverse, de $n-1$ jusqu'à $0$.</p>
# </div>

# %% [markdown]
# > 💻 **Question 8 —** En utilisant les fonctions `upper`, `lower` et `np.linalg.cholesky`, écrire une fonction `resolvcholesky(A,B)` qui prend en un argument une matrice $A$ qui admet une décomposition de Cholesky et un vecteur $B$ et rend le vecteur $X$, solution de l'équation $AX=B$.

# %% [markdown]
# > 💻 **Question 9 —** Retrouver la réponse de la question 1 à l'aide de la fonction resolcholesky.

# %% [markdown]
# <div style="background-color:#f5f5f5; border-left: 4px solid #333; padding: 8px 16px; margin: 20px 0;">
#   <h3 style="margin:0; color:#333;">Exercice 2 - Méthode de Jacobi</h3>
# </div>
#
# On s'intéresse à l'équation $A_2X=B_2$ où $A_2 = \begin{pmatrix} 10 & 2 & -1 & 1 \\ 1 & -8 & 2 & -1 \\ 2 & 1 & 9 & -2 \\ -1 & 1 & 2 & 7 \end{pmatrix}$ et $B_2 = \begin{pmatrix} 12 \\ -6 \\ 10 \\ 9 \end{pmatrix}$.

# %% [markdown]
# > 📝 **Question 10 —** À l'aide de l'algorithme du Pivot de Gauss, résoudre l'équation $A_1X=B_1$.

# %% [markdown]
# Le vecteur solution est $X=\begin{pmatrix} ? \\ ? \\ ? \\ ? \\ \end{pmatrix}$.

# %% [markdown]
# > 💻 **Question 11 —** Coder la matrice $A_2$ et le vecteur $B_2$ en Python.

# %% [markdown]
# > 📝 **Question 12 —** La méthode de Jacobi est-elle convergente pour ce système linéaire ? Justifier votre réponse.

# %% [markdown]
# Blablabla ...

# %% [markdown]
# > 💻 **Question 13 —** À l'aide de la fonction `np.linalg.eig`, écrire une fonction `rayonspectral(A)` qui prend une matrice $A$ en argument en renvoie son rayon spectral.

# %% [markdown]
# > 💻 **Question 14 —** On écrit $A_2=D+L+U$ où $D$ est la diagonale de $A_2$, $L$ sa partie triangulaire inférieure et $U$ sa partie triangulaire supérieure. Écrire trois fonctions `partdiag(A)`, `partinf(A)` et `partsup(A)` qui renvoient ces parties.

# %% [markdown]
# > 💻 **Question 15 —** Vérifier que ces trois fonctions fonctionnent correctement avec $A_2$.

# %% [markdown]
# > 💻 **Question 16 —** Écrire une fonction `diagsolve(D,Y)` qui prend en argument une matrice diagonale $D$ et un vecteur $Y$ et renvoie le vecteur $X$, solution de l'équation $AX=Y$.

# %% [markdown]
# > 💻 **Question 17 —** Écrire une fonction `jacobi(A, B, tol)` qui prend en argument une matrice $A$, un vecteur $B$ et une tolérance `tol`, et renvoie une approximation du vecteur $X$ solution de $AX=B$ par la méthode de Jacobi. Le critère d'arrêt sera `np.linalg.norm(np.dot(A, X) - B) < tol`.

# %% [markdown]
# > 💻 **Question 18 —** Tester la fonction `jacobi` sur la matrice $A_2$ et le vecteur $B_2$ avec une tolérance de $10^{-6}$. Vérifier que le résultat est cohérent avec la question 10.

# %% [markdown]
# > 💻 **Question 19 —** Modifier la fonction `jacobi` en une fonction `jacobi2(A, B, tol)` qui, en plus de renvoyer le vecteur solution $X$, renvoie le nombre d'itérations effectuées.

# %% [markdown]
# > 💻 **Question 20 —** Combien d'itérations sont nécessaires pour approcher la solution à $10^{-10}$ ?
